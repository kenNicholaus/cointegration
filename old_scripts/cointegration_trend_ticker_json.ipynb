# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import coint
from tqdm import tqdm
import pickle

# %%
read_file = '../../../sp500/prices/adjclose.csv'

# %%
df = pd.read_csv(read_file, index_col = 0, parse_dates = True)

# %%
tickers=df.columns.tolist()
len_tickers = len(tickers)

# %%
symbols = df.columns.tolist()
cointegration = {}

for symbol in symbols:
    temp = []
    df1=df.dropna(subset=[symbol])
    df1.fillna(0,inplace=True)
    for ticker in tickers[:]:
        if symbol != ticker:
            coint_t, p_value, crit_value = coint(df1[symbol].values, df1[ticker].values,trend='ct')
            if p_value < 0.05:
                temp.append(ticker)
    cointegration[symbol] = temp
    print(symbol, len(cointegration[symbol]))
# Out:
# C:\Users\kenneth\Anaconda3\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs
# A 62
# AAL 4
# AAP 14
# AAPL 36
# ABBV 19
# ABC 29
# ABMD 86
# ABT 82
# ACN 74
# ADBE 17
# ADI 32
# ADM 278
# ADP 74
# ADS 2
# ADSK 34
# AEE 35
# AEP 172
# AES 2
# AFL 100
# AIG 2
# AIV 3
# AIZ 17
# AJG 47
# AKAM 526
# ALB 13
# ALGN 129
# ALK 37
# ALL 3
# ALLE 453
# ALXN 9
# AMAT 36
# AMCR 138
# AMD 18
# AME 53
# AMGN 104
# AMP 46
# AMT 9
# AMZN 32
# ANET 7
# ANSS 12
# ANTM 36
# AON 97
# AOS 51
# APA 12
# APD 88
# APH 87
# APTV 93
# ARE 5
# ATO 90
# ATVI 31
# AVB 4
# AVGO 31
# AVY 44
# AWK 35
# AXP 101
# AZO 41
# BA 131
# BAC 2
# BAX 99
# BBY 44
# BDX 118
# BEN 11
# BF-B 78
# BIIB 44
# BK 5
# BKNG 94
# BKR 173
# BLK 32
# BLL 162
# BMY 28
# BR 46
# BRK-B 48
# BSX 0
# BWA 13
# BXP 12
# C 2
# CAG 178
# CAH 6
# CARR 17
# CAT 138
# CB 45
# CBOE 19
# CBRE 18
# CCI 5
# CCL 3
# CDNS 2
# CDW 24
# CE 36
# CERN 54
# CF 0
# CFG 17
# CHD 117
# CHRW 510
# CHTR 15
# CI 183
# CINF 172
# CL 69
# CLX 180
# CMA 5
# CMCSA 59
# CME 10
# CMG 1
# CMI 86
# CMS 21
# CNC 47
# CNP 63
# COF 19
# COG 17
# COO 125
# COP 38
# COST 100
# COTY 5
# CPB 4
# CPRT 40
# CRM 58
# CSCO 2
# CSX 74
# CTAS 48
# CTL 129
# CTSH 13
# CTVA 117
# CTXS 88
# CVS 40
# CVX 45
# CXO 49
# D 51
# DAL 7
# DD 53
# DE 125
# DFS 139
# DG 13
# DGX 33
# DHI 12
# DHR 48
# DIA 55
# DIS 146
# DISCA 4
# DISCK 11
# DISH 0
# DLR 31
# DLTR 79
# DOV 153
# DOW 41
# DPZ 66
# DRE 2
# DRI 34
# DTE 132
# DUK 165
# DVA 7
# DVN 38
# DX-Y.NYB 0
# DXC 3
# DXCM 1
# EA 5
# EBAY 15
# ECL 112
# ED 157
# EFX 113
# EIX 122
# EL 42
# EMN 20
# EMR 292
# EOG 3
# EQIX 191
# EQR 7
# ES 140
# ESS 41
# ETFC 6
# ETN 105
# ETR 30
# EVRG 123
# EW 52
# EXC 2
# EXPD 15
# EXPE 38
# EXR 18
# F 1
# FANG 13
# FAST 31
# FB 484
# FBHS 97
# FCX 18
# FDX 18
# FE 1
# FFIV 4
# FIS 66
# FISV 64
# FITB 0
# FLIR 119
# FLS 22
# FLT 31
# FMC 29
# FOX 36
# FOXA 36
# FRC 33
# FRT 43
# FTI 15
# FTNT 26
# FTV 13
# GD 59
# GE 0
# GILD 18
# GIS 88
# GL 81
# GLW 514
# GM 67
# GOOG 92
# GPC 113
# GPN 49
# GPS 3
# GRMN 3
# GS 48
# GWW 148
# HAL 59
# HAS 97
# HBAN 1
# HBI 6
# HCA 6
# HD 54
# HES 420
# HFC 112
# HIG 3
# HII 34
# HLT 7
# HOG 0
# HOLX 12
# HON 150
# HPE 17
# HPQ 7
# HRB 153
# HRL 162
# HSIC 39
# HST 38
# HSY 129
# HUM 112
# HWM 28
# IBM 3
# ICE 61
# IDXX 68
# IEX 67
# IFF 125
# ILMN 89
# INCY 175
# INFO 210
# INTC 31
# INTU 42
# IP 32
# IPG 3
# IPGP 1
# IQV 148
# IR 21
# IRM 503
# ISRG 8
# IT 43
# ITW 134
# IVZ 0
# J 15
# JBHT 89
# JCI 4
# JKHY 86
# JNJ 132
# JNPR 41
# JPM 173
# JWN 22
# K 164
# KEY 6
# KEYS 12
# KHC 6
# KIM 2
# KLAC 45
# KMB 96
# KMI 0
# KMX 348
# KO 82
# KR 43
# KSS 2
# KSU 78
# L 10
# LB 7
# LDOS 9
# LEG 160
# LEN 3
# LH 2
# LHX 95
# LIN 15
# LKQ 23
# LLY 29
# LMT 97
# LNC 11
# LNT 135
# LOW 142
# LRCX 52
# LUV 32
# LVS 2
# LW 19
# LYB 85
# LYV 52
# MA 20
# MAA 45
# MAR 55
# MAS 19
# MCD 149
# MCHP 105
# MCK 9
# MCO 9
# MDLZ 28
# MDT 34
# MET 41
# MGM 0
# MHK 3
# MKC 138
# MKTX 23
# MLM 64
# MMC 20
# MMM 107
# MNST 72
# MO 70
# MOS 59
# MPC 26
# MRK 24
# MRO 8
# MS 3
# MSCI 19
# MSFT 7
# MSI 8
# MTB 24
# MTD 62
# MU 42
# MXIM 1
# MYL 14
# NBL 5
# NCLH 3
# NDAQ 2
# NEE 73
# NEM 19
# NFLX 81
# NI 129
# NKE 83
# NLOK 46
# NLSN 26
# NOC 102
# NOV 11
# NOW 16
# NRG 1
# NSC 111
# NTAP 75
# NTRS 57
# NUE 29
# NVDA 6
# NVR 103
# NWL 0
# NWS 88
# NWSA 63
# O 126
# ODFL 28
# OKE 202
# OMC 37
# ORCL 34
# ORLY 56
# OTIS 362
# OXY 3
# PAYC 52
# PAYX 102
# PBCT 2
# PCAR 92
# PEAK 27
# PEG 54
# PEP 142
# PFE 17
# PFG 7
# PG 71
# PGR 62
# PH 226
# PHM 1
# PKG 23
# PKI 200
# PLD 2
# PM 39
# PNC 260
# PNR 104
# PNW 171
# PPG 58
# PPL 28
# PRGO 0
# PRU 15
# PSA 89
# PSX 400
# PVH 19
# PWR 8
# PXD 11
# PYPL 25
# QCOM 164
# QRVO 17
# RCL 127
# RE 141
# REG 5
# REGN 39
# RF 3
# RHI 277
# RJF 125
# RL 6
# RMD 54
# ROK 133
# ROL 127
# ROP 57
# ROST 86
# RSG 58
# RTX 153
# SBAC 16
# SBUX 93
# SCHW 9
# SEE 1
# SHW 95
# SIVB 195
# SJM 66
# SLB 11
# SLG 2
# SNA 92
# SNPS 11
# SO 49
# SPG 1
# SPGI 44
# SPY 15
# SRE 35
# STE 51
# STT 198
# STX 7
# STZ 32
# SWK 223
# SWKS 57
# SYF 20
# SYK 65
# SYY 199
# T 6
# TAP 9
# TDG 218
# TEL 43
# TFC 195
# TFX 87
# TGT 85
# TIF 344
# TJX 63
# TMO 44
# TMUS 32
# TPR 1
# TROW 126
# TRV 133
# TSCO 11
# TSN 138
# TT 135
# TTWO 21
# TWTR 34
# TXN 45
# TXT 8
# UA 6
# UAA 4
# UAL 7
# UDR 88
# UHS 82
# ULTA 15
# UNH 76
# UNM 0
# UNP 61
# UPS 165
# URI 57
# USB 99
# V 46
# VAR 216
# VFC 56
# VIAC 12
# VLO 66
# VMC 47
# VNO 9
# VRSK 33
# VRSN 38
# VRTX 85
# VTR 79
# VZ 35
# WAB 26
# WAT 102
# WBA 18
# WDC 68
# WEC 126
# WELL 162
# WFC 76
# WHR 162
# WLTW 134
# WM 39
# WMB 29
# WMT 71
# WRB 162
# WRK 6
# WST 36
# WU 266
# WY 40
# WYNN 2
# XEL 126
# XLB 144
# XLE 13
# XLF 4
# XLI 47
# XLK 13
# XLNX 31
# XLP 26
# XLU 44
# XLV 36
# XLY 40
# XOM 13
# XRAY 54
# XRT 12
# XRX 0
# XYL 8
# YUM 91
# ZBH 39
# ZBRA 54
# ZION 8
# ZTS 21
# ^GSPC 17
# ^IXIC 40
# ^NDX 4
# ^SOX 8
# ^TNX 0
# ^VIX 526
# ^VVIX 526
# ^VXN 512
# ^VXO 526
# ^VXV 224

# %%
print(len(cointegration))
# Out:
# 527

# %%
with open("../cointegration_tickers_trend.pickle","wb") as f:
        pickle.dump(cointegration,f)

# %%
with open("../cointegration_tickers_trend.pickle",'rb') as f:
            cointegration=pickle.load(f)
print(cointegration)
# Out:
# {'A': ['ADI', 'ADP', 'AEP', 'AJG', 'AMAT', 'AMD', 'AON', 'APH', 'BAX', 'BR', 'CCI', 'CHD', 'CLX', 'CMS', 'CRM', 'DIA', 'DLR', 'DOV', 'DPZ', 'DUK', 'EQIX', 'ES', 'EVRG', 'GOOG', 'HUM', 'ICE', 'IDXX', 'INTC', 'JKHY', 'LLY', 'LNT', 'MCD', 'MCHP', 'MRK', 'MSI', 'MTD', 'MU', 'MXIM', 'NFLX', 'NSC', 'PAYX', 'PEP', 'PH', 'PKI', 'ROL', 'ROP', 'SBAC', 'SPY', 'TDG', 'TROW', 'TXN', 'VRSN', 'VRTX', 'WEC', 'XEL', 'XLK', 'XLNX', 'XLU', '^GSPC', '^IXIC', '^NDX', '^SOX'], 'AAL': ['IFF', 'IPG', 'JCI', 'UPS'], 'AAP': ['ABC', 'BIIB', 'CAH', 'COTY', 'GILD', 'HRB', 'HSIC', 'KR', 'MCK', 'MYL', 'PSA', 'UAA', 'UHS', 'WBA'], 'AAPL': ['ABT', 'AMT', 'AMZN', 'ANSS', 'APD', 'AWK', 'BLL', 'CCI', 'CLX', 'COST', 'CTXS', 'DG', 'DPZ', 'EQIX', 'ES', 'FTNT', 'HWM', 'IDXX', 'KLAC', 'MKC', 'MKTX', 'MSCI', 'NEE', 'NFLX', 'NOW', 'ODFL', 'RMD', 'SBAC', 'STE', 'TDG', 'TMUS', 'TT', 'VRTX', 'WEC', 'WST', 'XEL'], 'ABBV': ['ATVI', 'AZO', 'BLK', 'EMN', 'GPS', 'IPGP', 'JBHT', 'KMB', 'MAA', 'MDLZ', 'MU', 'O', 'ORLY', 'PEAK', 'SBUX', 'TTWO', 'UNH', 'URI', 'WELL'], 'ABC': ['AAP', 'AMCR', 'APTV', 'BIIB', 'BMY', 'CAG', 'CERN', 'CL', 'D', 'DIS', 'GILD', 'GPC', 'HSIC', 'INCY', 'KMX', 'LEG', 'LYB', 'NCLH', 'NWS', 'NWSA', 'PPG', 'PSA', 'PSX', 'REGN', 'SNA', 'TWTR', 'UHS', 'WAB', 'WHR'], 'ABMD': ['ACN', 'ADP', 'AEP', 'AFL', 'ALGN', 'ANET', 'ANTM', 'AON', 'APH', 'ATO', 'ATVI', 'AVGO', 'BA', 'BAX', 'BDX', 'BR', 'BRK-B', 'CBOE', 'CDW', 'CFG', 'CHTR', 'CI', 'CINF', 'CNC', 'COO', 'COST', 'CSX', 'DE', 'DRI', 'DTE', 'ED', 'FISV', 'FTV', 'HII', 'HON', 'HPE', 'IEX', 'INFO', 'IR', 'ITW', 'JKHY', 'JNJ', 'JPM', 'KEYS', 'LHX', 'LMT', 'LNT', 'LW', 'LYV', 'MAR', 'MCD', 'MCHP', 'MKC', 'MTD', 'NOC', 'NSC', 'NVR', 'PAYX', 'PEP', 'PGR', 'PH', 'PKI', 'PNC', 'PNW', 'RCL', 'RE', 'ROK', 'ROL', 'ROP', 'RSG', 'SIVB', 'STZ', 'SWK', 'SYK', 'SYY', 'TDG', 'TFX', 'TTWO', 'UNH', 'URI', 'VAR', 'WAT', 'WM', 'WRK', 'XEL', 'XYL'], 'ABT': ['AAPL', 'ADP', 'ADSK', 'AEP', 'AJG', 'ALGN', 'AMT', 'AMZN', 'ANSS', 'AON', 'APD', 'AWK', 'BAX', 'BLL', 'CCI', 'CDW', 'CLX', 'COST', 'CPRT', 'CRM', 'CSX', 'CTAS', 'CTXS', 'DG', 'DHR', 'DOV', 'DPZ', 'ECL', 'EL', 'EQIX', 'ES', 'ETN', 'EW', 'FAST', 'FIS', 'FISV', 'FTNT', 'GPN', 'HWM', 'IDXX', 'INTU', 'JKHY', 'KEYS', 'KLAC', 'LHX', 'LOW', 'LRCX', 'LYV', 'MA', 'MCD', 'MCHP', 'MCO', 'MKC', 'NEE', 'NFLX', 'NKE', 'NSC', 'ODFL', 'PAYC', 'PGR', 'PH', 'PKI', 'RMD', 'ROP', 'SBAC', 'SHW', 'SPGI', 'STE', 'TDG', 'TFX', 'TIF', 'TMO', 'TMUS', 'TROW', 'TT', 'V', 'VRTX', 'WEC', 'WRB', 'XEL', 'ZBRA', 'ZTS'], 'ACN': ['A', 'ABT', 'ADI', 'ADP', 'AEE', 'AEP', 'AJG', 'AMZN', 'AON', 'APA', 'APH', 'ATO', 'AVGO', 'AWK', 'BAX', 'BF-B', 'BLL', 'CDW', 'CHD', 'CLX', 'CMS', 'CNC', 'COST', 'CRM', 'CTAS', 'CTL', 'DLR', 'DPZ', 'ED', 'EQIX', 'ES', 'EW', 'FIS', 'FISV', 'FTI', 'GOOG', 'HD', 'IDXX', 'INTC', 'INTU', 'JKHY', 'KEYS', 'LLY', 'LNT', 'MKC', 'MTD', 'NBL', 'NEE', 'NFLX', 'OXY', 'PAYX', 'PEP', 'PGR', 'PKI', 'ROL', 'ROP', 'ROST', 'SBAC', 'SHW', 'SLB', 'STE', 'TDG', 'TFX', 'TXN', 'UNH', 'V', 'VRSN', 'VRTX', 'WEC', 'WLTW', 'WM', 'WMT', 'XEL', 'ZTS'], 'ADBE': ['ADSK', 'AMZN', 'CPRT', 'HWM', 'KEYS', 'KLAC', 'LRCX', 'MKTX', 'NFLX', 'NVDA', 'PAYC', 'PYPL', 'RMD', 'SPGI', 'TT', 'WST', 'ZBRA'], 'ADI': ['A', 'ADP', 'AJG', 'ALGN', 'AMGN', 'AMZN', 'CLX', 'COST', 'CTAS', 'CTXS', 'DPZ', 'DUK', 'EQIX', 'HD', 'JKHY', 'JNJ', 'JPM', 'LLY', 'LOW', 'MMC', 'NFLX', 'PAYX', 'PGR', 'PKI', 'TT', 'TTWO', 'TXN', 'VRSN', 'VRTX', 'WMT', 'XLK', 'XLNX'], 'ADM': ['AAL', 'AAP', 'ABBV', 'ABC', 'ADS', 'AEP', 'AIG', 'AIZ', 'ALB', 'ALK', 'ALL', 'ALLE', 'ALXN', 'AMCR', 'AME', 'AMGN', 'AMP', 'ANET', 'AOS', 'APH', 'APTV', 'ARE', 'ATO', 'ATVI', 'AVB', 'AWK', 'AZO', 'BA', 'BAX', 'BDX', 'BEN', 'BF-B', 'BIIB', 'BLK', 'BLL', 'BR', 'BRK-B', 'BWA', 'BXP', 'C', 'CAG', 'CAT', 'CB', 'CBOE', 'CBRE', 'CCI', 'CE', 'CERN', 'CF', 'CFG', 'CHD', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMCSA', 'CME', 'CMI', 'CNC', 'COG', 'COO', 'COP', 'COST', 'COTY', 'CTSH', 'CVS', 'CVX', 'D', 'DAL', 'DE', 'DFS', 'DG', 'DIS', 'DISCA', 'DLR', 'DLTR', 'DRI', 'DTE', 'DUK', 'DVA', 'EBAY', 'ECL', 'E ...
