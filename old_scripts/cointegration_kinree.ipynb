# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import coint
from tqdm import tqdm
import warnings; warnings.simplefilter('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/aiTradeSignals/^GSPC_7_days_0_return.csv', index_col = 0, parse_dates = True)
df = df.dropna()

# %%
def getCoint(stock_name_1,stock_name_2, rolling_window=14):
  coint_values = [0]*(rolling_window-1)
  for i in tqdm(range(len(stocks[stock_name_1])-rolling_window+1)):
  #for i in tqdm(range(7)):
    y_stock_1 = df[stock_name_1][i:i+rolling_window]
    y_stock_2 = df[stock_name_2][i:i+rolling_window]
    coint_t, p_value, crit_value = coint(y_stock_1, y_stock_2)
    coint_values.append(coint_t)

  df_coint = df.iloc[:,0:0]
  print('df_len', len(df_coint))
  print('conit_vals len', len(coint_values))
  print(coint_values)
  df_coint['coint'] = coint_values
  
  df_coint.to_csv ('/content/drive/My Drive/aiTradeSignals/cointegration_results_{}_{}_{}.csv'.format(stock_name_1,stock_name_2, rolling_window), index = False, header=True)
  return df_coint

# %%
x = getCoint('A', 'AAL')
x
# Out:
# ...
# 100%|██████████| 12614/12614 [00:35<00:00, 358.42it/s]
# df_len 12627
# conit_vals len 12627
# ...
